# %%
# zip fit to minimum len

l1 = [1,2,3,4]
l2 = [-1, -2, -3]

for a, b in zip(l1, l2):
    print(a,b, a==b)
# Out:
# 1 -1 False
# 2 -2 False
# 3 -3 False

# %%
# Counter return 0 if null
from collections import Counter
cnt = Counter(['a', 'a', 'b'])
print(cnt['a'])
print(cnt['c'])
# Out:
# 2
# 0

# %%
# string func
'abc'.startswith('a')
# Out:
# True
